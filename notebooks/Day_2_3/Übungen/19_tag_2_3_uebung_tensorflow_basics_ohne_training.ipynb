# %% [markdown]
# # Übung: TensorFlow-Basics ohne Modelltraining
#
# **Erlaubte Bibliotheken:** `numpy`, `pandas`, `matplotlib`, `tensorflow` und `keras` aus der vorhandenen Kursumgebung.
#
# ## Lernziele
#
# - einen kleinen wiederverwendbaren Mini-Datensatz erzeugen und dokumentieren
# - Tensoren erstellen und Shapes lesen
# - Batches, Features und Outputs unterscheiden
# - Matrixmultiplikation als Kern eines Dense-Layers verstehen
# - Aktivierungsfunktionen vergleichen
# - einfache Loss-Werte berechnen und interpretieren
# - mit `tf.GradientTape` eine Ableitung berechnen
# - typische Shape-Fehler systematisch debuggen

# %% [markdown]
# ## Aufgabe 1 - Setup prüfen
#
# Importieren Sie die benötigten Bibliotheken. Geben Sie TensorFlow-Version, verfügbare Geräte und einen festen Random Seed aus.
#
# Minimaler Hinweis:
# - `tf.__version__`
# - `tf.config.list_physical_devices()`
# - `tf.keras.utils.set_random_seed(...)`

# %% [markdown]
# **Auszufüllen:**
#
# - TensorFlow-Version: ____________________
# - Läuft eine GPU in dieser Umgebung? ____________________
# - Warum ist ein Random Seed in Übungen hilfreich?
#
# Antwort:

# %% [markdown]
# ## Aufgabe 2 - Gemeinsamen Mini-Datensatz erzeugen
#
# Erzeugen Sie einen kleinen Mini-Datensatz, der in den späteren Aufgaben weiterverwendet wird.
#
# Der Datensatz soll enthalten:
#
# - `x`: Feature-Matrix mit 4 Samples und 3 Features
# - `y_reg`: Zielwerte für eine Regression mit Shape `(4, 1)`
# - `y_bin`: Zielwerte für binäre Klassifikation mit Shape `(4, 1)`
# - `y_multi`: Klassenlabels für Mehrklassen-Klassifikation mit Shape `(4,)`
#
# Nutzen Sie bewusst kleine, lesbare Werte. Die Features können fiktiv sein, z. B. `age`, `monthly_spend` und `support_tickets`. Verwenden Sie diesen Datensatz in den Aufgaben zu Dense-Layer, Output-Formen, Loss und Gradienten wieder.
#
# Minimaler Hinweis:
# - `tf.constant(...)` für bewusst gesetzte Werte
# - `dtype=tf.float32` für numerische Features und Regressions-/Binärziele
# - `dtype=tf.int32` für Sparse-Mehrklassenlabels
# - `.shape`, `.dtype` und `tf.rank(...)` zur Kontrolle

# %% [markdown]
# **Auszufüllen:**
#
# | Objekt | Shape | dtype | Bedeutung |
# | --- | --- | --- | --- |
# | `x` |  |  |  |
# | `y_reg` |  |  |  |
# | `y_bin` |  |  |  |
# | `y_multi` |  |  |  |
#
# - Welche Achse ist bei `x` die Sample-Achse?
# - Welche Achse ist bei `x` die Feature-Achse?
# - Warum ist `y_multi` eindimensional, wenn später `SparseCategoricalCrossentropy` genutzt wird?
#
# Antwort:

# %% [markdown]
# ## Aufgabe 3 - Broadcasting mit dem Mini-Datensatz verstehen
#
# Nutzen Sie `x` aus Aufgabe 2. Berechnen Sie Mittelwert und Standardabweichung pro Feature und standardisieren Sie `x` manuell.
#
# Speichern Sie das Ergebnis als `x_scaled`. Dieses `x_scaled` wird in den nächsten Aufgaben als Eingabe für den Dense-Layer, die Output-Beispiele und den Gradienten verwendet.
#
# Prüfen Sie danach, ob die standardisierten Features ungefähr Mittelwert 0 und Standardabweichung 1 haben.
#
# Minimaler Hinweis:
# - `tf.reduce_mean(x, axis=0)`
# - `tf.math.reduce_std(x, axis=0)`
# - Broadcasting passiert bei `x - mean` automatisch.

# %% [markdown]
# **Auszufüllen:**
#
# - Shape von `x`: ____________________
# - Shape von `x_scaled`: ____________________
# - Shape des Feature-Mittelwerts: ____________________
# - Warum funktioniert `x - mean`, obwohl beide Tensoren unterschiedliche Shapes haben?
#
# Antwort:

# %% [markdown]
# ## Aufgabe 4 - Dense-Layer von Hand rechnen
#
# Bauen Sie einen Dense-Layer ohne Keras-Layer nach. Verwenden Sie als Eingabe `x_scaled` aus Aufgabe 3.
#
# ```text
# z_hidden = x_scaled @ w_hidden + b_hidden
# a_hidden = relu(z_hidden)
# ```
#
# Legen Sie die Gewichte bewusst selbst fest:
# - `x_scaled`: 4 Samples, 3 Features
# - `w_hidden`: 3 Input-Features, 2 Neuronen, also Shape `(3, 2)`
# - `b_hidden`: 2 Bias-Werte, also Shape `(2,)`
#
# Berechnen Sie `z_hidden` und `a_hidden`. Diese beiden Tensoren werden in Aufgabe 6 wiederverwendet. Prüfen Sie alle Shapes.

# %% [markdown]
# **Auszufüllen:**
#
# - Shape von `x_scaled`: ____________________
# - Shape von `w_hidden`: ____________________
# - Shape von `b_hidden`: ____________________
# - Shape von `z_hidden`: ____________________
# - Shape von `a_hidden`: ____________________
# - Warum muss die zweite Dimension von `x_scaled` zur ersten Dimension von `w_hidden` passen?
#
# Antwort:

# %% [markdown]
# ## Aufgabe 5 - Aktivierungsfunktionen vergleichen
#
# Erzeugen Sie Werte von -5 bis 5 und plotten Sie mindestens:
#
# - lineare Aktivierung
# - ReLU
# - sigmoid
# - tanh
# - optional Leaky ReLU
#
# Minimaler Hinweis:
# - `tf.nn.relu(...)`
# - `tf.nn.sigmoid(...)`
# - `tf.nn.tanh(...)`

# %% [markdown]
# **Auszufüllen:**
#
# - Welche Aktivierung ist für versteckte Dense-Layer oft ein guter Startpunkt?
# - Welche Aktivierung passt zu binärer Klassifikation am Output?
# - Welche Aktivierung passt zu Mehrklassen-Klassifikation am Output?
#
# Antwort:

# %% [markdown]
# ## Aufgabe 6 - Output-Formen für verschiedene Aufgaben
#
# Nutzen Sie `a_hidden` aus Aufgabe 4 als gemeinsame Eingabe für drei kleine Output-Layer. Sie bauen also drei verschiedene Köpfe auf denselben Hidden-Output:
#
# - Regression: `y_reg_pred = a_hidden @ w_reg_out + b_reg_out`
# - binäre Klassifikation: `y_bin_pred = sigmoid(a_hidden @ w_bin_out + b_bin_out)`
# - Mehrklassen-Klassifikation: `y_multi_pred = softmax(a_hidden @ w_multi_out + b_multi_out)`
#
# Legen Sie die Output-Gewichte selbst passend zu den Shapes fest:
# - `w_reg_out`: Shape `(2, 1)`
# - `w_bin_out`: Shape `(2, 1)`
# - `w_multi_out`: Shape `(2, 4)` für 4 Klassen
#
# Prüfen Sie die Shapes und interpretieren Sie, was eine Zeile im Output bedeutet.
#
# Minimaler Hinweis:
# - Regression: meist `(batch, 1)` ohne Aktivierung
# - binär: meist `(batch, 1)` mit Sigmoid
# - Mehrklasse: meist `(batch, n_classes)` mit Softmax

# %% [markdown]
# **Auszufüllen:**
#
# | Aufgabe | verwendeter Output | Output-Shape | passende letzte Aktivierung | typische Loss-Funktion |
# | --- | --- | --- | --- | --- |
# | Regression | `y_reg_pred` |  |  |  |
# | Binäre Klassifikation | `y_bin_pred` |  |  |  |
# | Mehrklassen-Klassifikation | `y_multi_pred` |  |  |  |

# %% [markdown]
# ## Aufgabe 7 - Loss manuell und mit Keras berechnen
#
# Nutzen Sie die Targets aus Aufgabe 2 und die Vorhersagen aus Aufgabe 6:
#
# - Regression: `y_reg` gegen `y_reg_pred`
# - binäre Klassifikation: `y_bin` gegen `y_bin_pred`
# - Mehrklassen-Klassifikation: `y_multi` gegen `y_multi_pred`
#
# Berechnen Sie:
#
# - Mean Squared Error für Regression
# - Binary Crossentropy für binäre Klassifikation
# - Sparse Categorical Crossentropy für Mehrklassen-Klassifikation
#
# Vergleichen Sie eine manuelle Rechnung mit der Keras-Loss-Funktion.
#
# Minimaler Hinweis:
# - Nutzen Sie bewusst denselben Mini-Batch mit 4 Samples aus Aufgabe 2.
# - `y_bin_pred` und `y_multi_pred` sind Wahrscheinlichkeiten, keine Logits.
# - Wenn Sie stattdessen Logits verwenden, muss `from_logits=True` gesetzt werden.

# %% [markdown]
# **Auszufüllen:**
#
# - Regression-Loss mit `y_reg` und `y_reg_pred`: ____________________
# - Binary-Crossentropy mit `y_bin` und `y_bin_pred`: ____________________
# - Sparse-Categorical-Crossentropy mit `y_multi` und `y_multi_pred`: ____________________
# - Wann ist MSE sinnvoll?
# - Warum ist Crossentropy für Klassifikation meistens passender als MSE?
# - Was bedeutet ein hoher Loss-Wert fachlich?
#
# Antwort:

# %% [markdown]
# ## Aufgabe 8 - Ein einzelner Gradient ohne Training
#
# Nutzen Sie `tf.GradientTape`, um die Ableitung eines Loss nach den Gewichten eines kleinen Regressions-Neurons zu berechnen.
#
# Verwenden Sie dafür:
# - Eingabe: `x_scaled` aus Aufgabe 3
# - Ziel: `y_reg` aus Aufgabe 2
# - Gewicht: neues `tf.Variable` namens `w_single` mit Shape `(3, 1)`
# - Bias: neues `tf.Variable` namens `b_single` mit Shape `(1,)`
# - Vorhersage: `y_single_pred = x_scaled @ w_single + b_single`
# - Loss: Mean Squared Error zwischen `y_reg` und `y_single_pred`
#
# Berechnen Sie die Gradienten nach `w_single` und `b_single`, aber aktualisieren Sie die Variablen noch nicht.

# %% [markdown]
# **Auszufüllen:**
#
# - Shape von `w_single`: ____________________
# - Shape von `b_single`: ____________________
# - Loss: ____________________
# - Shape des Gradienten für `w_single`: ____________________
# - Gradient für `b_single`: ____________________
# - In welche Richtung müssten `w_single` und `b_single` verändert werden, damit der Loss kleiner wird?
#
# Antwort:

# %% [markdown]
# ## Aufgabe 9 - Eine manuelle Update-Rechnung auf Papier und im Code
#
# Verwenden Sie `w_single`, `b_single` und die Gradienten aus Aufgabe 8. Führen Sie genau einen Gradientenabstieg-Schritt aus:
#
# ```text
# w_neu = w_alt - lernrate * gradient_w
# b_neu = b_alt - lernrate * gradient_b
# ```
#
# Berechnen Sie danach mit denselben Daten `x_scaled` und `y_reg` den Loss erneut. Es ist weiterhin kein Training im Sinne von `fit`, sondern nur ein einzelner Rechenschritt.

# %% [markdown]
# **Auszufüllen:**
#
# - Lernrate: ____________________
# - `w_single` vor dem Update: ____________________
# - `w_single` nach dem Update: ____________________
# - `b_single` vor dem Update: ____________________
# - `b_single` nach dem Update: ____________________
# - Loss vor dem Update: ____________________
# - Loss nach dem Update: ____________________
# - Ist der Loss kleiner geworden?
#
# Antwort:

# %% [markdown]
# ## Aufgabe 10 - Shape-Fehler debuggen
#
# Erzeugen Sie absichtlich einen Shape-Fehler bei einer Matrixmultiplikation mit `x_scaled` aus Aufgabe 3.
#
# Beispiel:
# - `x_scaled` hat Shape `(4, 3)`
# - ein falsches Gewicht `w_wrong` hat Shape `(2, 1)`
# - `x_scaled @ w_wrong` muss fehlschlagen, weil die inneren Dimensionen nicht passen
#
# Lesen Sie die Fehlermeldung und korrigieren Sie danach die Tensorformen, z. B. mit einem Gewicht der Shape `(3, 1)`.
#
# Minimaler Hinweis:
# - Ein häufiger Fehler ist `x @ w`, wenn die innere Dimension nicht passt.
# - Dokumentieren Sie nicht nur die Lösung, sondern auch den Grund des Fehlers.

# %% [markdown]
# **Auszufüllen:**
#
# - Fehlerhafte Shapes: ____________________
# - Kernaussage der Fehlermeldung: ____________________
# - Korrigierte Shapes: ____________________
# - Welche Regel merken Sie sich für Matrixmultiplikation?
#
# Antwort:

# %% [markdown]
# ## Aufgabe 11 - Abschlussreflexion
#
# Fassen Sie in eigenen Worten zusammen, was bei einem Dense-Layer mathematisch passiert und welche Rolle Loss und Gradient spielen.
#
# **Auszufüllen:**
#
# - Dense-Layer in einem Satz:
# - Loss in einem Satz:
# - Gradient in einem Satz:
# - Was ist Ihnen bei Tensor-Shapes noch unsicher?
#
# Antwort:
